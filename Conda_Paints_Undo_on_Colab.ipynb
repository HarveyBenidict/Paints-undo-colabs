# %% [markdown]
# <a href="https://colab.research.google.com/github/HarveyBenidict/Paints-undo-colabs/blob/main/Conda_Paints_Undo_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Paints-Undo
#
# https://github.com/lllyasviel/Paints-UNDO
#
# How to install conda on Google Colab
# https://towardsdatascience.com/conda-google-colab-75f7c867a522
#
#
# ## Article on AICU media
#
# ❏描画工程を推論する「Paints-Undo」、Google Colabで実際に動作させてみた
#
# Paints-Undo, which infers the drawing process, actually works with Google Colab.
# https://note.com/aicu/n/n7e654dcf405c
#
# YouTube
# https://youtube.com/shorts/IwLdjySq3Yk
# Share this code by https://j.aicu.ai/PaintsUndo

# %%
# !which python
# !python --version
# !echo $PYTHONPATH
# Out:
# /usr/local/bin/python
# Python 3.8.13
# /env/python

# %%
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# env: PYTHONPATH=

# %%
# %%bash
#
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# !python --version
# Out:
# /usr/local/bin/conda
# Python 3.6.5 :: Anaconda, Inc.

# %% [markdown]
# If all went well, it should return /usr/local/bin/conda
#
# python 3.6.5 :: Anaconda, Inc. and you will see that different versions of python are installed by miniconda.
# Let's upgrade python and libraries!
#
# Temporarily disable SSL because the update repository cannot be referenced as it is.

# %%
# !conda config --show-sources
# !conda config --show ssl_verify
# Out:
# ==> /root/.condarc <==
# ssl_verify: False
#
# ssl_verify: False

# %%
# !conda config --set ssl_verify false
# !conda install --channel defaults conda python=3.6 --yes
# !pip install tqdm
# !conda update --channel defaults --all --yes
# Out:
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "/usr/local/lib/python3.6/site-packages/conda/exceptions.py", line 1079, in __call__
#         return func(*args, **kwargs)
#       File "/usr/local/lib/python3.6/site-packages/conda/cli/main.py", line 84, in _main
#         exit_code = do_call(args, p)
#       File "/usr/local/lib/python3.6/site-packages/conda/cli/conda_argparse.py", line 83, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "/usr/local/lib/python3.6/site-packages/conda/cli/main_install.py", line 20, in execute
#         install(args, parser, 'install')
#       File "/usr/local/lib/python3.6/site-packages/conda/cli/install.py", line 116, in install
#         if context.use_only_tar_bz2:
#       File "/usr/local/lib/python3.6/site-packages/conda/base/context.py", line 745, in use_only_tar_bz2
#         import conda_package_handling.api
# ...

# %%
# !apt-get update
# !apt-get install ca-certificates -y
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Process is terminated.

# %%
# !conda update -n base conda -y
# Out:
# done
# |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# |
# CondaError: KeyboardInterrupt

# %%
# !conda --version # 4.10.3
# Out:
# conda 4.10.3

# %% [markdown]
# This is the end of conda installation.
# Next is the installation of Paints UNDO.

# %%
# !git clone https://github.com/lllyasviel/Paints-UNDO.git
# Out:
# fatal: destination path 'Paints-UNDO' already exists and is not an empty directory.

# %%
# %cd /content/Paints-UNDO
# !pip install -r requirements.txt
# !pip install diffusers==0.2.4

# Your current Python version is 3.6, which may not be compatible with the latest gradio; you need to upgrade your Python to 3.7 or higher.
# !conda install python=3.8 -y
# !python --version
# !pip install --upgrade pip
# !pip install gradio==3.0.12
# xformers...
#!pip install -U xformers

# %% [markdown]
# Remember to make the last line of gradio_app.py ``--share`` compliant before executing this cell!
#
# Change the last line of gradio_app.py as follows
#
# block.queue().launch(server_name='0.0.0.0')
#
# ↓
#
# block.queue().launch(server_name='0.0.0.0', share=True)

# %%
# !pip install torchvision
# !pip install --upgrade torch
# run
# !python gradio_app.py --share
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/9a/f5/b76d021f06e50f770d3f6c1a1b50b62a69e587b1f0db7248269c4be21206/torch-1.10.1-cp36-cp36m-manylinux1_x86_64.whl
# ...
# conda 4.10.3 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# ...
#   Found existing installation: torch 1.10.2
#     Uninstalling torch-1.10.2:
#       Successfully uninstalled torch-1.10.2
# ...
#   Using cached https://files.pythonhosted.org/packages/a4/54/81b1c3c574a1ffde54b0c82ed2a37d81395709cdd5f50e59970aeed5d95e/torch-1.10.2-cp36-cp36m-manylinux1_x86_64.whl
# Requirement not upgraded as not directly required: typing-extensions in /usr/local/lib/python3.6/site-packages (from torch) (4.1.1)
# Requirement not upgraded as not directly required: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/site-packages (from torch) (0.8)
# conda 4.10.3 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# ...
